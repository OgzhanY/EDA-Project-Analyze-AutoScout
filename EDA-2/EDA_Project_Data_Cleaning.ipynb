# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# # WELCOME!

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# The project consists of 3 parts:
# * First part is related with 'data cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, Dropping useless columns.
# * Second part is related with 'filling data'. It deals with Missing Values. Categorical to numeric transformation is done.
# * Third part is related with 'handling outliers of data' via Visualisation libraries. Some insights are extracted.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
import pandas as pd
import re
import numpy as np
import seaborn as sns
sns.set_style("whitegrid")

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

##pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.max_rows=100
pd.options.display.max_columns=100

# %%
scout_car = pd.read_json ('scout_car.json', lines = True)
df = scout_car.copy()
df.sample(3).T
# Out:
#                                                                            4989   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                                    SPB 1.6 TDI 116 CV Business
# body_type                                                                 Sedans
# price                                                                      21600
# vat                                                                         None
# km                                                                     26,600 km
# registration                                                             02/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# ...

# %%
df["registration"]=df["registration"].replace("-/-",np.nan)

# %%
df["registration"]
# Out:
# 0        01/2016
# 1        03/2017
# 2        02/2016
# 3        08/2016
# 4        05/2016
#           ...
# 15914        NaN
# 15915    01/2019
# 15916    03/2019
# 15917    06/2019
# 15918    01/2019
# Name: registration, Length: 15919, dtype: object

# %%
pd.DatetimeIndex(df['registration']).year
# Out:
# Float64Index([2016.0, 2017.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0, 2016.0,
#               2016.0, 2017.0,
#               ...
#               2019.0, 2019.0, 2019.0,    nan, 2019.0,    nan, 2019.0, 2019.0,
#               2019.0, 2019.0],
#              dtype='float64', name='registration', length=15919)

# %%
df['registration'].astype(str).str.split("-")
# Out:
# 0        [01/2016]
# 1        [03/2017]
# 2        [02/2016]
# 3        [08/2016]
# 4        [05/2016]
#            ...
# 15914        [nan]
# 15915    [01/2019]
# 15916    [03/2019]
# 15917    [06/2019]
# 15918    [01/2019]
# Name: registration, Length: 15919, dtype: object

# %%
df['registration']
# Out:
# 0        01/2016
# 1        03/2017
# 2        02/2016
# 3        08/2016
# 4        05/2016
#           ...
# 15914        NaN
# 15915    01/2019
# 15916    03/2019
# 15917    06/2019
# 15918    01/2019
# Name: registration, Length: 15919, dtype: object

# %%
df.shape
# Out:
# (15919, 54)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   14322 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
df.describe(include='object').T
# Out:
#                                count unique  \
# url                            15919  15919
# make_model                     15919      9
# short_description              15873  10001
# body_type                      15859      9
# vat                            11406      2
# km                             15919   6690
# registration                   14322     47
# prev_owner                      9091      4
# hp                             15919     81
# Type                           15917    169
# Previous Owners                 9279    102
# Next Inspection                 3535   1399
# Inspection new                  3932    202
# Warranty                       10499    515
# Full Service                    8215    122
# Non-smoking Vehicle             7177     94
# null                           15919      1
# Make                           15919      3
# Model                          15919      9
# Offer Number                   12744  11440
# ...

# %%
df.describe().T
# Out:
#          count          mean          std   min      25%      50%      75%  \
# price  15919.0  18019.896727  7386.169409  13.0  12850.0  16900.0  21900.0
# kW         0.0           NaN          NaN   NaN      NaN      NaN      NaN
#
#            max
# price  74600.0
# kW         NaN

# %% [markdown]
# ## Fix incorrect Headers

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
df.rename(columns={"\nComfort & Convenience\n":"Comfort & Convenience",
                  "\nEntertainment & Media\n":"Entertainment & Media",
                  "\nExtras\n":"Extras",
                  "\nSafety & Security\n":"Safety & Security"}, inplace=True)

# %%
from skimpy import clean_columns

# %%
df=clean_columns(df)
df.head(3)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
#
#                 vat         km registration         prev_owner  k_w      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners  NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None  NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner  NaN   85 kW
#
#                                       type previous_owners  \
# ...

# %% [markdown]
# # Examination Of Colomns

# %% [markdown]
# ## url

# %%
#eksik bilgileri bundan yararlanarak doldurabiliriz.
#onun için şimdilik tutuyoruz.
#keep

# %%
df['url'].value_counts
#df.rename(columns={'url':'drop_url'},inplace=True)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        https://www.autoscout24.com//offers/audi-a1-sp...
# 1        https://www.autoscout24.com//offers/audi-a1-1-...
# 2        https://www.autoscout24.com//offers/audi-a1-sp...
# 3        https://www.autoscout24.com//offers/audi-a1-1-...
# 4        https://www.autoscout24.com//offers/audi-a1-sp...
#                                ...
# 15914    https://www.autoscout24.com//offers/renault-es...
# 15915    https://www.autoscout24.com//offers/renault-es...
# 15916    https://www.autoscout24.com//offers/renault-es...
# 15917    https://www.autoscout24.com//offers/renault-es...
# 15918    https://www.autoscout24.com//offers/renault-es...
# Name: url, Length: 15919, dtype: object>

# %% [markdown]
# ## make_model

# %%
#ici full
#make , model ile connection var
#bu keep edilsin

# %%
df['make_model'].value_counts()
# Out:
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %% [markdown]
# ## make (Drop)

# %%
#make model ve model ile baglantili

# %%
df['make'].value_counts()
# Out:
# \nOpel\n       7343
# \nAudi\n       5712
# \nRenault\n    2864
# Name: make, dtype: int64

# %%
df['make'].isnull().sum()
# Out:
# 0

# %%
##df['Make'] = df['Make'].replace('\\n', '', regex=True) Alternative
df['make']=df["make"].str.strip("\n")

# %%
df['make'].value_counts()
# Out:
# Opel       7343
# Audi       5712
# Renault    2864
# Name: make, dtype: int64

# %% [markdown]
# ## model (Drop)

# %%
##make model ve make ile baglantili

# %%
df['model'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, A3, \n]          3097
# [\n, A1, \n]          2614
# [\n, Insignia, \n]    2598
# [\n, Astra, \n]       2526
# [\n, Corsa, \n]       2219
# [\n, Clio, \n]        1839
# [\n, Espace, \n]       991
# [\n, Duster, \n]        34
# [\n, A2, \n]             1
# Name: model, dtype: int64

# %%
df['model'].isnull().sum()
# Out:
# 0

# %%
##df["model"].str[1] 
df['model']=df['model'].apply(lambda x: x[1])

# %%
df['model']
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: model, Length: 15919, dtype: object

# %% [markdown]
# ## short_description

# %%
#46 null değer var.
#description ile baglantili 
#description icindeki tamamlanabilir

# %%
df['short_description'].value_counts()
# Out:
# SPB 1.6 TDI 116 CV S tronic Sport                 64
# 1.4 66kW (90CV) Selective                         40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH             38
# SPB 30 TDI S tronic Business                      35
# SPB 30 TFSI S tronic Admired                      35
#                                                   ..
# K Sports Tourer Business **Navi*Voll**             1
# 1.0 Turbo ecoFLEX Automatic Elective Park Navi     1
# 1.6 CDTI Business *Navi*Automatik*Spurh.*          1
# 1.6 136 CV Automatica Navi E 6 Garanzia Full       1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                1
# Name: short_description, Length: 10001, dtype: int64

# %%
df['short_description'].isnull().sum()
# Out:
# 46

# %% [markdown]
# ## description (Drop)

# %%
# short description ile aynı değerleri içeriyor.
# almanca bilgi var
#Bunun için bu sütunu eleyebiliriz

# %%
df['description'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ...

# %%
df['description'].isnull().sum()
# Out:
# 0

# %%
df[["short_description","description"]].sample(15)
# Out:
#                                        short_description  \
# 5982   1,0 Turbo ecoflex Dir. Inj. Edition Easytr. St./S
# 7029                     1.4 Turbo Automatik Navi Kamera
# 799           Sportback Sport 1.0 TFSI Navi PDC Sitzhzg.
# 15770         V Espace Initiale Paris Dci 160 Energy Edc
# 10473                ST 1.6 ECOTEC DI T Business Edition
# 15543  1.6 dCi 160cv Energy Initiale Paris EDC 4 Control
# 3560             1.2 TFSI S line Xenon Sitzheizung Klima
# 5269          Sportback 35 TFSI 150 S-tronic Nav PDC SHZ
# 1193                 Sportback 1.4 TDI sport media-paket
# 13472              1.2 LIMITED *Navi*Temp*R&Go*Garantie*
# 13291              1.2 TCE ENERGY INTENS Aut. *Navi*LED*
# 8353               1.4 5T Edition AT/PDC/Klima/Allwetter
# 8412                   1.4 LPG Hersteller-Garantie,Klima
# 3147   Sportback Attraction 2.0 TDI Einparkhilfe plus...
# 2103                                             30 TFSI
#
# ...

# %% [markdown]
# ## body_type

# %%
df['body_type'].value_counts()
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df['body_type'].isnull().sum()
# Out:
# 60

# %% [markdown]
# ## body

# %%
#body type ile iliskili 
#body dusebilir hemen hemn ayni bilgiler

# %%
df['body'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Sedans, \n]           7903
# [\n, Station wagon, \n]    3553
# [\n, Compact, \n]          3153
# [\n, Van, \n]               783
# [\n, Other, \n]             290
# [\n, Transporter, \n]        88
# [\n, Off-Road, \n]           56
# [\n, Coupe, \n]              25
# [\n, Convertible, \n]         8
# Name: body, dtype: int64

# %%
df['body'].isnull().sum()
# Out:
# 60

# %%
##df["Body"].str[1].str.strip("\n")
df["body"]=df['body'].apply(lambda x: np.nan if type(x)==float else x[1])

# %%
df["body"]
# Out:
# 0        Sedans
# 1        Sedans
# 2        Sedans
# 3        Sedans
# 4        Sedans
#           ...
# 15914       Van
# 15915       Van
# 15916       Van
# 15917       Van
# 15918       Van
# Name: body, Length: 15919, dtype: object

# %%
df[["body_type","body"]].value_counts()
# Out:
# body_type      body
# Sedans         Sedans           7903
# Station wagon  Station wagon    3553
# Compact        Compact          3153
# Van            Van               783
# Other          Other             290
# Transporter    Transporter        88
# Off-Road       Off-Road           56
# Coupe          Coupe              25
# Convertible    Convertible         8
# dtype: int64

# %% [markdown]
# ## vat

# %%
df['vat'].value_counts(dropna=False)
# Out:
# VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64

# %%
df['vat'].isnull().sum()
# Out:
# 4513

# %%
##df["vat"] = df["vat"].apply(lambda x: "Discount" if x != None else np.nan)

# %%
##df["vat"]

# %% [markdown]
# ## km

# %%
df['km'].value_counts()
# Out:
# 10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64

# %%
df['km'].isnull().sum()
# Out:
# 0

# %%
df["km"]=df["km"].replace({",":"","-":np.nan}, regex=True).str.strip(" km")

# %%
df["km"]
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#          ...
# 15914      NaN
# 15915     9900
# 15916       15
# 15917       10
# 15918      NaN
# Name: km, Length: 15919, dtype: object

# %% [markdown]
# ## registration and first registration

# %%
df[["registration", "first_registration"]]
# Out:
#       registration first_registration
# 0          01/2016     [\n, 2016, \n]
# 1          03/2017     [\n, 2017, \n]
# 2          02/2016     [\n, 2016, \n]
# 3          08/2016     [\n, 2016, \n]
# 4          05/2016     [\n, 2016, \n]
# ...            ...                ...
# 15914          NaN                NaN
# 15915      01/2019     [\n, 2019, \n]
# 15916      03/2019     [\n, 2019, \n]
# 15917      06/2019     [\n, 2019, \n]
# 15918      01/2019     [\n, 2019, \n]
#
# [15919 rows x 2 columns]

# %%
df[['registration', "first_registration"]].isnull().sum()
# Out:
# registration          1597
# first_registration    1597
# dtype: int64

# %%
df["first_registration"]=df["first_registration"].str[1]

# %%
df["first_registration"]=df["first_registration"].astype(float).astype('Int64')

# %%
df["first_registration"]
# Out:
# 0        2016
# 1        2017
# 2        2016
# 3        2016
# 4        2016
#          ...
# 15914    <NA>
# 15915    2019
# 15916    2019
# 15917    2019
# 15918    2019
# Name: first_registration, Length: 15919, dtype: Int64

# %%
#tarih verisi 
#ici temiz
#keep
#first registration ile baglantili

# %%
df['registration']=df['registration'].replace('-/-',np.nan,regex=True)

# %%
df['registration']
# Out:
# 0        01/2016
# 1        03/2017
# 2        02/2016
# 3        08/2016
# 4        05/2016
#           ...
# 15914        NaN
# 15915    01/2019
# 15916    03/2019
# 15917    06/2019
# 15918    01/2019
# Name: registration, Length: 15919, dtype: object

# %%
df['registration']=pd.to_datetime(df['registration'])
df['registration']
# Out:
# 0       2016-01-01
# 1       2017-03-01
# 2       2016-02-01
# 3       2016-08-01
# 4       2016-05-01
#            ...
# 15914          NaT
# 15915   2019-01-01
# 15916   2019-03-01
# 15917   2019-06-01
# 15918   2019-01-01
# Name: registration, Length: 15919, dtype: datetime64[ns]

# %%
df["first_registration"]
# Out:
# 0        2016
# 1        2017
# 2        2016
# 3        2016
# 4        2016
#          ...
# 15914    <NA>
# 15915    2019
# 15916    2019
# 15917    2019
# 15918    2019
# Name: first_registration, Length: 15919, dtype: Int64

# %%
df["age"] = 2020 - df["first_registration"]

# %%
df["age"]
# Out:
# 0           4
# 1           3
# 2           4
# 3           4
# 4           4
#          ...
# 15914    <NA>
# 15915       1
# 15916       1
# 15917       1
# 15918       1
# Name: age, Length: 15919, dtype: Int64

# %% [markdown]
# ## prev_owner

# %%
df['prev_owner'].value_counts(dropna=False)
# Out:
# 1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64

# %%
df['prev_owner'].isnull().sum()
# Out:
# 6828

# %%
df[["prev_owner","previous_owners"]].head(10)
# Out:
#           prev_owner previous_owners
# 0  2 previous owners           \n2\n
# 1               None             NaN
# 2   1 previous owner           \n1\n
# 3   1 previous owner           \n1\n
# 4   1 previous owner           \n1\n
# 5   1 previous owner           \n1\n
# 6   1 previous owner           \n1\n
# 7   1 previous owner           \n1\n
# 8   1 previous owner           \n1\n
# 9               None             NaN

# %%
df['prev_owner']=df['prev_owner'].str.split(" ").str[0]

# %%
df['prev_owner']
# Out:
# 0           2
# 1        None
# 2           1
# 3           1
# 4           1
#          ...
# 15914    None
# 15915       1
# 15916       1
# 15917    None
# 15918       1
# Name: prev_owner, Length: 15919, dtype: object

# %%
df['prev_owner'].value_counts(dropna=False)
# Out:
# 1      8294
# NaN    6828
# 2       778
# 3        17
# 4         2
# Name: prev_owner, dtype: int64

# %% [markdown]
# ## previous owners

# %%
df['previous_owners'].value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# \n1\n                                                                                        8101
# NaN                                                                                          6640
# \n2\n                                                                                         766
# \n0\n                                                                                         163
# ...

# %%
df['previous_owners'].isnull().sum()
# Out:
# 6640

# %%
df["previous_owners"] = df["previous_owners"].apply(lambda x: x[0] if type(x) == list else x).replace('\\n', '', regex=True)

# %%
df['previous_owners'].value_counts(dropna=False)
# Out:
# 1      8294
# NaN    6640
# 2       778
# 0       188
# 3        17
# 4         2
# Name: previous_owners, dtype: int64

# %% [markdown]
# ## kW (Drop)

# %%
df['k_w']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 15914   NaN
# 15915   NaN
# 15916   NaN
# 15917   NaN
# 15918   NaN
# Name: k_w, Length: 15919, dtype: float64

# %%
df['k_w'].isnull().sum()
# Out:
# 15919

# %% [markdown]
# ## hp

# %%
df['hp'].value_counts()
# Out:
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# - kW        88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 82 kW       22
# 52 kW       22
# 78 kW       20
# 1 kW        20
# 294 kW      18
# 146 kW      18
# 141 kW      16
# 57 kW       10
# 104 kW       8
# 120 kW       8
# 191 kW       7
# 112 kW       7
# 155 kW       6
# 117 kW       6
# 184 kW       5
# 90 kW        4
# 76 kW        4
# 65 kW        4
# 149 kW       3
# 80 kW        3
# 168 kW       3
# 98 kW        3
# 93 kW        3
# 228 kW       2
# 270 kW       2
# ...

# %%
df['hp']=df['hp'].replace({'[ kW]': '', '-': np.nan}, regex=True).astype('float').astype('Int64')
df['hp']
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         66
#         ...
# 15914    147
# 15915    165
# 15916    146
# 15917    147
# 15918    165
# Name: hp, Length: 15919, dtype: Int64

# %% [markdown]
# ## Type

# %%
df['type'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [, Used, , Diesel (Particulate Filter)]                                                                                 3475
# [, Used, , Diesel]                                                                                                      2516
# [, Used, , Gasoline]                                                                                                    2367
# ...

# %%
df['type'].isnull().sum()
# Out:
# 2

# %%
df['type']=df['type'].str[1].str.strip("\n")

# %%
df['type']
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: type, Length: 15919, dtype: object

# %%
used = ['Used', "Employee's car", 'Demonstration']
new = ["New", "Pre-registered"]

# %%
def usage(x):
    if x in used:
        x = "Used"
    elif x in new:
        x = "New"
    return x

# %%
df["type"] = df["type"].apply(usage)
df["type"].value_counts(dropna=False)
# Out:
# Used    12903
# New      3014
# NaN         2
# Name: type, dtype: int64

# %% [markdown]
# ## Next Inspection vs Inspection new

# %%
# Muayne bilgisi fiyata ettiki etmeyen bir parametre olduğu için sutün'u düşürmek yerinde bir karar olur.
# Eğer fiyata ettiki etseydi, sutünün %77'sinin null değer olmasına rağmen düşürmek yerine değerleri anlamlı bir şekide doldurmaya çalışırdık.
#drop edilsin cok iliskili degil anlamli yok

# %%
df[["next_inspection","inspection_new"]].sample(15)
# Out:
#                               next_inspection  \
# 13851                                     NaN
# 1936                                      NaN
# 9469                                      NaN
# 218    [\n06/2020\n, \n109 g CO2/km (comb)\n]
# 2982                                      NaN
# 15544                                     NaN
# 10319  [\n04/2022\n, \n129 g CO2/km (comb)\n]
# 15321                                     NaN
# 3896                                      NaN
# 3349                                      NaN
# 1547             [\n03/2021\n, \n4 (Green)\n]
# 8363                                      NaN
# 11910                                     NaN
# 15246                                     NaN
# 11275                                     NaN
#
#                                        inspection_new
# 13851                                             NaN
# 1936                                              NaN
# 9469                                              NaN
# ...

# %%
df[["next_inspection","inspection_new"]].isnull().sum()
# Out:
# next_inspection    12384
# inspection_new     11987
# dtype: int64

# %%
# Muayne bilgisi fiyata ettiki etmeyen bir parametre olduğu için sutün'u düşürmek yerinde bir karar olur.
#icinde yes 102 co2 flan gibi degerler var
# Eğer fiyata ettiki etseydi, sutünün %75'nin null değer olmasına rağmen düşürmek yerine değerleri anlamlı bir şekide doldurmaya çalışırdık.
#drop edilsin anlamli veri yok

# %%
df['next_inspection'].sample(18)
# Out:
# 4901                                                   NaN
# 2220                                                   NaN
# 904                                                    NaN
# 3451                                                   NaN
# 8444                                                   NaN
# 10424                                                  NaN
# 12673                                                  NaN
# 4668                                                   NaN
# 12654                                                  NaN
# 8713                [\n03/2021\n, \n126 g CO2/km (comb)\n]
# 9430                                                   NaN
# 4999                                                   NaN
# 5347                                                   NaN
# 3039                                                   NaN
# 7743     [\n06/2022\n, \n, 5.8 l/100 km (comb), \n, 7.4...
# 1333                                                   NaN
# ...

# %%
df['next_inspection'] = df['next_inspection'].apply(lambda x: np.nan if type(x) == float else x[0]).replace("\\n","",regex=True)
df['next_inspection']
# Out:
# 0        06/2021
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 15914        NaN
# 15915    01/2022
# 15916        NaN
# 15917        NaN
# 15918        NaN
# Name: next_inspection, Length: 15919, dtype: object

# %%
df['next_inspection']=pd.to_datetime(df['next_inspection'])
df['next_inspection']
# Out:
# 0       2021-06-01
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
#            ...
# 15914          NaT
# 15915   2022-01-01
# 15916          NaT
# 15917          NaT
# 15918          NaT
# Name: next_inspection, Length: 15919, dtype: datetime64[ns]

# %%
df["inspection_new"][8859]
# Out:
# ['\nYes\n', '\n128 g CO2/km (comb)\n']

# %%
df["inspection_new"] = df["inspection_new"].apply(lambda x: np.nan if type(x) == float else x[0]).replace("\\n","",regex=True)
df["inspection_new"]
# Out:
# 0        Yes
# 1        NaN
# 2        NaN
# 3        NaN
# 4        Yes
#         ...
# 15914    NaN
# 15915    NaN
# 15916    Yes
# 15917    NaN
# 15918    Yes
# Name: inspection_new, Length: 15919, dtype: object

# %% [markdown]
# ## CO2 Emission

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'k_w', 'hp', 'type',
#        'previous_owners', 'next_inspection', 'inspection_new', 'warranty',
#        'full_service', 'non_smoking_vehicle', 'null', 'make', 'model',
#        'offer_number', 'first_registration', 'body_color', 'paint_type',
#        'body_color_original', 'upholstery', 'body', 'nr_of_doors',
#        'nr_of_seats', 'model_code', 'gearing_type', 'displacement',
#        'cylinders', 'weight', 'drive_chain', 'fuel', 'consumption',
#        'co_2_emission', 'emission_class', 'comfort_&_convenience',
#        'entertainment_&_media', 'extras', 'safety_&_security', 'description',
#        'emission_label', 'gears', 'country_version', 'electricity_consumption',
#        'last_service_date', 'other_fuel_types', 'availability',
#        'last_timing_belt_service_date', 'available_from', 'age'],
#       dtype='object')

# %%
df["co_2_emission"]
# Out:
# 0         [\n99 g CO2/km (comb)\n]
# 1        [\n129 g CO2/km (comb)\n]
# 2         [\n99 g CO2/km (comb)\n]
# 3         [\n99 g CO2/km (comb)\n]
# 4        [\n109 g CO2/km (comb)\n]
#                    ...
# 15914    [\n139 g CO2/km (comb)\n]
# 15915    [\n168 g CO2/km (comb)\n]
# 15916    [\n139 g CO2/km (comb)\n]
# 15917    [\n139 g CO2/km (comb)\n]
# 15918    [\n153 g CO2/km (comb)\n]
# Name: co_2_emission, Length: 15919, dtype: object

# %%
df['co_2_emission']=df['co_2_emission'].apply(lambda x: np.nan if type(x) == float else x[0]).replace("\\n", "", regex=True)

# %%
df['co_2_emission']=df['co_2_emission'].replace("[]",np.nan)

# %%
df['co_2_emission']=df['co_2_emission'].str.split(" ").str[0]
df['co_2_emission']
# Out:
# 0         99
# 1        129
# 2         99
# 3         99
# 4        109
#         ...
# 15914    139
# 15915    168
# 15916    139
# 15917    139
# 15918    153
# Name: co_2_emission, Length: 15919, dtype: object

# %%
df['co_2_emission']=df['co_2_emission'].replace(",","")

# %%
df['co_2_emission'].value_counts()
# Out:
# 120       740
# 99        545
# 97        537
# 104       501
# 102       477
#          ...
# 80          1
# 51          1
# 165         1
# 12,324      1
# 193         1
# Name: co_2_emission, Length: 122, dtype: int64

# %% [markdown]
# ## emission_class (Drop)

# %%
def list_clear(x):
    if type(x)==float: 
        return np.nan 
    elif type(x[0])==list:
        return np.nan
    else:
        return x[0]

# %%
df['emission_class']=df['emission_class'].apply(list_clear).replace("\\n", "", regex=True)
df['emission_class']
# Out:
# 0              Euro 6
# 1              Euro 6
# 2              Euro 6
# 3              Euro 6
# 4              Euro 6
#              ...
# 15914             NaN
# 15915             NaN
# 15916    Euro 6d-TEMP
# 15917          Euro 6
# 15918          Euro 6
# Name: emission_class, Length: 15919, dtype: object

# %%
df["emission_class"].value_counts()
# Out:
# Euro 6          10139
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64

# %% [markdown]
# ## emission_label (Drop)

# %%
df["emission_label"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4 (Green)\n]         3553
# [\n1 (No sticker)\n]     381
# [[], [], []]              40
# [\n5 (Blue)\n]             8
# [\n3 (Yellow)\n]           2
# [\n2 (Red)\n]              1
# Name: emission_label, dtype: int64

# %%
df["emission_label"] = df["emission_label"].str[0].str.split().str[1].str.strip("()")
df["emission_label"]
# Out:
# 0          NaN
# 1        Green
# 2        Green
# 3          NaN
# 4          NaN
#          ...
# 15914      NaN
# 15915      NaN
# 15916      NaN
# 15917      NaN
# 15918    Green
# Name: emission_label, Length: 15919, dtype: object

# %%
df["emission_label"].value_counts()
# Out:
# Green     3553
# No         381
# Blue         8
# Yellow       2
# Red          1
# Name: emission_label, dtype: int64

# %% [markdown]
# ## Warranty

# %%
df['warranty'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n, \nEuro 6\n]                                                                               1868
# \n12 months\n                                                                                      1177
# \n                                                                                                  979
# \n24 months\n                                                                                       566
# ...

# %%
df['warranty'].isnull().sum()
# Out:
# 5420

# %%
def list_clear(x):
    if type(x)==float: 
        return np.nan 
    elif type(x[0])==list:
        return np.nan
    else:
        return x[0]

# %%
df['warranty'] = df['warranty'].apply(list_clear).replace("\\n", "", regex=True)
df['warranty']
# Out:
# 0
# 1        NaN
# 2
# 3        NaN
# 4
#         ...
# 15914
# 15915
# 15916
# 15917
# 15918    NaN
# Name: warranty, Length: 15919, dtype: object

# %%
df['warranty'].value_counts()
# Out:
#              7703
# 12 months    1417
# 24 months     552
# 60 months     382
# 36 months     223
# 6 months       49
# 72 months      44
# 48 months      40
# 3 months       14
# 23 months      10
# 18 months       7
# 20 months       7
# 25 months       5
# 50 months       4
# 16 months       4
# 2 months        4
# 34 months       3
# 1 months        2
# 11 months       2
# 14 months       2
# 45 months       2
# 22 months       2
# 21 months       2
# 17 months       2
# 46 months       2
# 26 months       2
# 13 months       2
# 65 months       1
# 33 months       1
# 28 months       1
# 15 months       1
# 7 months        1
# 19 months       1
# 10 months       1
# 56 months       1
# 49 months       1
# 47 months       1
# 40 months       1
# Name: warranty, dtype: int64

# %% [markdown]
# ## Full Service

# %%
df['full_service']
# Out:
# 0                                [\n, \n]
# 1                                     NaN
# 2                                     NaN
# 3        [\n, \n, \n99 g CO2/km (comb)\n]
# 4                 [\n, \n, \n4 (Green)\n]
#                        ...
# 15914                                 NaN
# 15915                                 NaN
# 15916                            [\n, \n]
# 15917                                 NaN
# 15918                                 NaN
# Name: full_service, Length: 15919, dtype: object

# %%
df["full_service"] =df["full_service"].str[2].str.strip("\n")

# %%
df["full_service"]
# Out:
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3        99 g CO2/km (comb)
# 4                 4 (Green)
#                 ...
# 15914                   NaN
# 15915                   NaN
# 15916                   NaN
# 15917                   NaN
# 15918                   NaN
# Name: full_service, Length: 15919, dtype: object

# %% [markdown]
# ## Non-smoking Vehicle  (Drop)

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'k_w', 'hp', 'type',
#        'previous_owners', 'next_inspection', 'inspection_new', 'warranty',
#        'full_service', 'non_smoking_vehicle', 'null', 'make', 'model',
#        'offer_number', 'first_registration', 'body_color', 'paint_type',
#        'body_color_original', 'upholstery', 'body', 'nr_of_doors',
#        'nr_of_seats', 'model_code', 'gearing_type', 'displacement',
#        'cylinders', 'weight', 'drive_chain', 'fuel', 'consumption',
#        'co_2_emission', 'emission_class', 'comfort_&_convenience',
#        'entertainment_&_media', 'extras', 'safety_&_security', 'description',
#        'emission_label', 'gears', 'country_version', 'electricity_consumption',
#        'last_service_date', 'other_fuel_types', 'availability',
#        'last_timing_belt_service_date', 'available_from', 'age'],
#       dtype='object')

# %%
df['non_smoking_vehicle'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, \n]                                                                                      3647
# [\n, \n, \n4 (Green)\n]                                                                       1240
# [\n, \n, \nEuro 6\n]                                                                          1127
# [\n, \n, \nEuro 6d-TEMP\n]                                                                     345
# ...

# %%
df['non_smoking_vehicle'].isnull().sum()
# Out:
# 8742

# %%
df["non_smoking_vehicle"] =df["non_smoking_vehicle"].str[2].str.strip("\n")
df['non_smoking_vehicle']
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3           Euro 6
# 4              NaN
#            ...
# 15914          NaN
# 15915    4 (Green)
# 15916          NaN
# 15917          NaN
# 15918          NaN
# Name: non_smoking_vehicle, Length: 15919, dtype: object

# %%
df['non_smoking_vehicle'].value_counts()
# Out:
# 4 (Green)              1240
# Euro 6                 1127
# Euro 6d-TEMP            345
# 120 g CO2/km (comb)      63
# 85 g CO2/km (comb)       46
# 104 g CO2/km (comb)      36
# 107 g CO2/km (comb)      36
# 153 g CO2/km (comb)      31
# 124 g CO2/km (comb)      29
# 1 (No sticker)           24
# 99 g CO2/km (comb)       23
# 106 g CO2/km (comb)      20
# 97 g CO2/km (comb)       20
# 108 g CO2/km (comb)      19
# 109 g CO2/km (comb)      18
# 105 g CO2/km (comb)      18
# 100 g CO2/km (comb)      18
# 113 g CO2/km (comb)      18
# Euro 6c                  17
#                          16
# 98 g CO2/km (comb)       15
# 129 g CO2/km (comb)      14
# 131 g CO2/km (comb)      13
# 103 g CO2/km (comb)      12
# 114 g CO2/km (comb)      12
# 133 g CO2/km (comb)      12
# 135 g CO2/km (comb)      11
# 102 g CO2/km (comb)      11
# 116 g CO2/km (comb)      11
# 127 g CO2/km (comb)      10
# 143 g CO2/km (comb)      10
# Euro 6d                   9
# 92 g CO2/km (comb)        9
# ...

# %% [markdown]
# ## Offer Number (Drop)

# %%
df["offer_number"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nLT67679\n]                                     27
# [\nAK13780\n]                                     27
# [\nTP62881\n]                                     27
# [\nTA76392\n]                                     27
# [\nXT61649\n]                                     27
#                                                   ..
# [\n160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b\n]     1
# ...

# %%
df["offer_number"].isnull().sum()
# Out:
# 3175

# %%
df["offer_number"]=df["offer_number"].apply(lambda x: np.nan if type(x)==float else x[0]).replace("\\n","",regex=True)
df["offer_number"]
# Out:
# 0             LR-062483
# 1                   NaN
# 2              AM-95365
# 3                   NaN
# 4                 C1626
#               ...
# 15914          10988301
# 15915       507370_3223
# 15916          Espace16
# 15917           2691331
# 15918    Re_30000008029
# Name: offer_number, Length: 15919, dtype: object

# %%
df["offer_number"].value_counts()
# Out:
# LT67679                                     27
# AK13780                                     27
# TP62881                                     27
# TA76392                                     27
# XT61649                                     27
#                                             ..
# 160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b     1
# 6701576                                      1
# 6701569                                      1
# 158121                                       1
# Re_30000008029                               1
# Name: offer_number, Length: 11440, dtype: int64

# %% [markdown]
# ## Body Color vs Body Color Orjinal vs Paint Type

# %%
df["body_color"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Black, \n]     3745
# [\n, Grey, \n]      3505
# [\n, White, \n]     3406
# [\n, Silver, \n]    1647
# [\n, Blue, \n]      1431
# [\n, Red, \n]        957
# [\n, Brown, \n]      289
# [\n, Green, \n]      154
# [\n, Beige, \n]      108
# [\n, Yellow, \n]      51
# [\n, Violet, \n]      18
# [\n, Bronze, \n]       6
# [\n, Orange, \n]       3
# [\n, Gold, \n]         2
# Name: body_color, dtype: int64

# %%
df["body_color_original"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nOnyx Schwarz\n]                     338
# [\nBianco\n]                           282
# [\nMythosschwarz Metallic\n]           238
# [\nBrillantschwarz\n]                  216
# [\nGris\n]                             204
#                                       ...
# [\nRouge-Braun (G0Y)\n]                  1
# [\nVARI COLRI DISPONIBILI\n]             1
# [\nKokosnussbraun Metallic\n]            1
# ...

# %%
df["paint_type"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nMetallic\n]       9794
# [\nUni/basic\n]       347
# [\nPerl effect\n]       6
# Name: paint_type, dtype: int64

# %%
df[["body_color","body_color_original","paint_type"]].isnull().sum()
# Out:
# body_color              597
# body_color_original    3759
# paint_type             5772
# dtype: int64

# %%
df["body_color"] = df["body_color"].str[1].str.strip("\n")
df["body_color"]
# Out:
# 0        Black
# 1          Red
# 2        Black
# 3        Brown
# 4        Black
#          ...
# 15914     Grey
# 15915     Grey
# 15916    White
# 15917     Grey
# 15918     Grey
# Name: body_color, Length: 15919, dtype: object

# %%
df["paint_type"] = df["paint_type"].str[0].str.strip("\n")
df["paint_type"]
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: paint_type, Length: 15919, dtype: object

# %%
df["body_color_original"] = df["body_color_original"].str[0].str.strip("\n")
df["body_color_original"]
# Out:
# 0                 Mythosschwarz
# 1                           NaN
# 2        mythosschwarz metallic
# 3                           NaN
# 4        Mythosschwarz Metallic
#                   ...
# 15914              Grigio scuro
# 15915       Stahl-Grau Metallic
# 15916               arktis-weiß
# 15917                    Grigio
# 15918    Titanium-Grau Metallic
# Name: body_color_original, Length: 15919, dtype: object

# %% [markdown]
# ## Upholstery

# %%
df["upholstery"].isnull().sum()
# Out:
# 3720

# %%
df["upholstery"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nCloth, Black\n]           5821
# [\nPart leather, Black\n]    1121
# [\nCloth\n]                  1005
# [\nCloth, Grey\n]             891
# [\nCloth, Other\n]            639
# [\nFull leather, Black\n]     575
# [\nBlack\n]                   491
# [\nGrey\n]                    273
# [\nOther, Other\n]            182
# [\nPart leather\n]            140
# [\nFull leather\n]            139
# ...

# %%
df["upholstery"] =df["upholstery"].str[0].str.strip("\n")

# %%
df["upholstery"]
# Out:
# 0               Cloth, Black
# 1                Cloth, Grey
# 2               Cloth, Black
# 3                        NaN
# 4               Cloth, Black
#                 ...
# 15914                    NaN
# 15915                  Cloth
# 15916    Full leather, Black
# 15917           Part leather
# 15918    Full leather, Brown
# Name: upholstery, Length: 15919, dtype: object

# %% [markdown]
# ## Nr. of Doors

# %%
df["nr_of_doors"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    11575
# [\n4\n]     3079
# [\n3\n]      832
# [\n2\n]      219
# [\n1\n]        1
# [\n7\n]        1
# Name: nr_of_doors, dtype: int64

# %%
df["nr_of_doors"].isnull().sum()
# Out:
# 212

# %%
df["nr_of_doors"] = df["nr_of_doors"].str[0].replace("\\n","",regex=True)
df["nr_of_doors"].value_counts()
# Out:
# 5    11575
# 4     3079
# 3      832
# 2      219
# 1        1
# 7        1
# Name: nr_of_doors, dtype: int64

# %% [markdown]
# ## Nr. of Seats

# %%
df["nr_of_seats"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n5\n]    13336
# [\n4\n]     1125
# [\n7\n]      362
# [\n2\n]      116
# [\n6\n]        2
# [\n3\n]        1
# Name: nr_of_seats, dtype: int64

# %%
df["nr_of_seats"].isnull().sum()
# Out:
# 977

# %%
df["nr_of_seats"] =df["nr_of_seats"].str[0].str.strip("\n")
df["nr_of_seats"].value_counts()
# Out:
# 5    13336
# 4     1125
# 7      362
# 2      116
# 6        2
# 3        1
# Name: nr_of_seats, dtype: int64

# %% [markdown]
# ## Model Code

# %%
df["model_code"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0035/BCB\n]    268
# [\n0588/BNO\n]    245
# [\n0588/BDB\n]    206
# [\n0588/BHX\n]    188
# [\n1844/ADJ\n]    175
#                  ...
# [\n0000/ACP\n]      1
# [\n0035/BGY\n]      1
# [\n0035/bgp\n]      1
# [\n0035/BGS\n]      1
# [\n3333/BKG\n]      1
# Name: model_code, Length: 232, dtype: int64

# %%
df["model_code"].isnull().sum()
# Out:
# 10941

# %%
df["model_code"] = df["model_code"].str[0].str.strip("\n")
df["model_code"]
# Out:
# 0        0588/BDF
# 1        0588/BCY
# 2             NaN
# 3             NaN
# 4        0588/BDF
#            ...
# 15914         NaN
# 15915    0000/000
# 15916         NaN
# 15917         NaN
# 15918    3333/BHJ
# Name: model_code, Length: 15919, dtype: object

# %% [markdown]
# ## Gearing Type vs Gears

# %%
df["gearing_type"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Manual, \n]            8153
# [\n, Automatic, \n]         7297
# [\n, Semi-automatic, \n]     469
# Name: gearing_type, dtype: int64

# %%
df["gears"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n6\n]     5822
# [\n5\n]     3239
# [\n7\n]     1908
# [\n8\n]      224
# [\n9\n]        6
# [\n1\n]        2
# [\n3\n]        2
# [\n4\n]        2
# [\n2\n]        1
# [\n50\n]       1
# Name: gears, dtype: int64

# %%
df[["gearing_type","gears"]].isnull().sum()
# Out:
# gearing_type       0
# gears           4712
# dtype: int64

# %%
df["gearing_type"]=df["gearing_type"].str[1].str.strip("\n")
df["gearing_type"]
# Out:
# 0        Automatic
# 1        Automatic
# 2        Automatic
# 3        Automatic
# 4        Automatic
#            ...
# 15914    Automatic
# 15915    Automatic
# 15916    Automatic
# 15917    Automatic
# 15918    Automatic
# Name: gearing_type, Length: 15919, dtype: object

# %%
df["gears"] = df.gears.str[0].str.strip("\n")
df["gears"].value_counts()
# Out:
# 6     5822
# 5     3239
# 7     1908
# 8      224
# 9        6
# 1        2
# 3        2
# 4        2
# 2        1
# 50       1
# Name: gears, dtype: int64

# %% [markdown]
# ## Displacement

# %%
df["displacement"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n1,598 cc\n]     4761
# [\n999 cc\n]       2438
# [\n1,398 cc\n]     1314
# [\n1,399 cc\n]      749
# [\n1,229 cc\n]      677
# [\n1,956 cc\n]      670
# [\n1,461 cc\n]      595
# [\n1,490 cc\n]      559
# [\n1,422 cc\n]      467
# [\n1,197 cc\n]      353
# [\n898 cc\n]        351
# [\n1,395 cc\n]      320
# [\n1,968 cc\n]      301
# [\n1,149 cc\n]      288
# [\n1,618 cc\n]      212
# [\n1,798 cc\n]      210
# ...

# %%
df["displacement"].isnull().sum()
# Out:
# 496

# %%
df["displacement"] = df["displacement"].str[0].str.strip("\n")
df["displacement"]
# Out:
# 0        1,422 cc
# 1        1,798 cc
# 2        1,598 cc
# 3        1,422 cc
# 4        1,422 cc
#            ...
# 15914    1,997 cc
# 15915    1,798 cc
# 15916    1,997 cc
# 15917    1,997 cc
# 15918    1,798 cc
# Name: displacement, Length: 15919, dtype: object

# %%
df.replace({"displacement" : {"," : "", " " : "", "cc" : ""}}, regex = True, inplace = True)

# %%
df["displacement"].value_counts()
# Out:
# 1598     4761
# 999      2438
# 1398     1314
# 1399      749
# 1229      677
# 1956      670
# 1461      595
# 1490      559
# 1422      467
# 1197      353
# 898       351
# 1395      320
# 1968      301
# 1149      288
# 1618      212
# 1798      210
# 1498      196
# 1600      130
# 1248      110
# 1997      103
# 1364      102
# 1400       90
# 998        72
# 1500       50
# 2000       46
# 1000       40
# 1          36
# 1998       25
# 2480       20
# 1200       18
# 1984       18
# 1397       11
# 899        11
# 160         6
# 929         5
# 1499        5
# 997         4
# 1596        4
# 139         4
# 900         4
# 1599        3
# 1199        3
# 1396        3
# 1495        2
# 1589        2
# 1300        2
# 2           2
# 995         2
# 1496        1
# 890         1
# 1580        1
# 1995        1
# 1333        1
# 54          1
# 1533        1
# 1100        1
# 1350        1
# 16000       1
# 1856        1
# 1568        1
# 1896        1
# 1584        1
# ...

# %% [markdown]
# ## Cylinders

# %%
df["cylinders"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n4\n]    8105
# [\n3\n]    2104
# [\n5\n]      22
# [\n6\n]       3
# [\n8\n]       2
# [\n2\n]       2
# [\n1\n]       1
# Name: cylinders, dtype: int64

# %%
df["cylinders"].isnull().sum()
# Out:
# 5680

# %%
df["cylinders"] =df["cylinders"].str[0].str.strip("\n")
df["cylinders"]
# Out:
# 0          3
# 1          4
# 2        NaN
# 3          3
# 4          3
#         ...
# 15914      4
# 15915      4
# 15916      4
# 15917      4
# 15918      4
# Name: cylinders, Length: 15919, dtype: object

# %%
df["cylinders"].value_counts()
# Out:
# 4    8105
# 3    2104
# 5      22
# 6       3
# 8       2
# 2       2
# 1       1
# Name: cylinders, dtype: int64

# %% [markdown]
# ## Weight (Drop)

# %%
df["weight"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n1,163 kg\n]    574
# [\n1,360 kg\n]    356
# [\n1,165 kg\n]    301
# [\n1,335 kg\n]    242
# [\n1,135 kg\n]    213
#                  ...
# [\n1,331 kg\n]      1
# [\n1,132 kg\n]      1
# [\n1,252 kg\n]      1
# [\n1,792 kg\n]      1
# [\n2,037 kg\n]      1
# Name: weight, Length: 434, dtype: int64

# %%
df["weight"].isnull().sum()
# Out:
# 6974

# %%
df["weight"] = df["weight"].str[0].str.strip("\n kg").str.replace(",",".")
df["weight"]
# Out:
# 0        1.220
# 1        1.255
# 2          NaN
# 3        1.195
# 4          NaN
#          ...
# 15914    1.758
# 15915    1.708
# 15916      NaN
# 15917    1.758
# 15918    1.685
# Name: weight, Length: 15919, dtype: object

# %%
df["weight"].value_counts()
# Out:
# 1.163    574
# 1.360    356
# 1.165    301
# 1.335    242
# 1.135    213
#         ...
# 1.331      1
# 1.132      1
# 1.252      1
# 1.792      1
# 2.037      1
# Name: weight, Length: 434, dtype: int64

# %% [markdown]
# ## Drive chain

# %%
df["drive_chain"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nfront\n]    8886
# [\n4WD\n]       171
# [\nrear\n]        4
# Name: drive_chain, dtype: int64

# %%
df["drive_chain"].isnull().sum()
# Out:
# 6858

# %%
df["drive_chain"] = df["drive_chain"].str[0].str.strip("\n")
df["drive_chain"]
# Out:
# 0        front
# 1        front
# 2        front
# 3          NaN
# 4        front
#          ...
# 15914    front
# 15915    front
# 15916    front
# 15917    front
# 15918      4WD
# Name: drive_chain, Length: 15919, dtype: object

# %%
df["drive_chain"].value_counts()
# Out:
# front    8886
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64

# %% [markdown]
# ## Fuel vs Electricity Consumption (Drop)  vs Other Fuel Types (Drop)

# %%
df["fuel"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n, Diesel (Particulate Filter), \n]                                                                                                       4315
# [\n, Super 95, \n]                                                                                                                          3338
# ...

# %%
df[["fuel","electricity_consumption","other_fuel_types"]].isnull().sum()
# Out:
# fuel                           0
# electricity_consumption    15782
# other_fuel_types           15039
# dtype: int64

# %%
df["electricity_consumption"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n0 kWh/100 km (comb)\n]    137
# Name: electricity_consumption, dtype: int64

# %%
df[["fuel","electricity_consumption","other_fuel_types"]].sample(15)
# Out:
#                                                     fuel  \
# 8500                                  [\n, Super 95, \n]
# 1499                                  [\n, Super 95, \n]
# 13241                                   [\n, Diesel, \n]
# 15142                                   [\n, Diesel, \n]
# 6612                                  [\n, Gasoline, \n]
# 5750               [\n, Diesel (Particulate Filter), \n]
# 10361                                 [\n, Gasoline, \n]
# 8194   [\n, Super 95 / Super E10 95 (Particulate Filt...
# 10672              [\n, Diesel (Particulate Filter), \n]
# 5493                                  [\n, Gasoline, \n]
# 4535                                    [\n, Diesel, \n]
# 5793                   [\n, Super 95 / Super E10 95, \n]
# 6769                                  [\n, Gasoline, \n]
# 7211               [\n, Diesel (Particulate Filter), \n]
# 11215              [\n, Diesel (Particulate Filter), \n]
#
#       electricity_consumption other_fuel_types
# ...

# %%
df["fuel"] = df.fuel.str[1].str.split("/").str[0].str.strip()
df["fuel"]
# Out:
# 0        Diesel (Particulate Filter)
# 1                           Gasoline
# 2        Diesel (Particulate Filter)
# 3        Diesel (Particulate Filter)
# 4        Diesel (Particulate Filter)
#                     ...
# 15914    Diesel (Particulate Filter)
# 15915                       Super 95
# 15916                         Diesel
# 15917                         Diesel
# 15918                       Super 95
# Name: fuel, Length: 15919, dtype: object

# %%
df["fuel"].value_counts()
# Out:
# Diesel (Particulate Filter)          4315
# Super 95                             4100
# Gasoline                             3175
# Diesel                               2984
# Regular                               503
# Super E10 95                          402
# Super 95 (Particulate Filter)         268
# Gasoline (Particulate Filter)          77
# CNG                                    33
# LPG                                    16
# Super Plus 98                          11
# Liquid petroleum gas (LPG)             10
# Super E10 95 (Particulate Filter)       7
# Electric                                5
# Others                                  5
# CNG (Particulate Filter)                3
# Super Plus E10 98                       2
# Others (Particulate Filter)             1
# Biogas                                  1
# Domestic gas H                          1
# Name: fuel, dtype: int64

# %%
df["fuel"] = df.fuel.str.split("(").str[0].str.strip()
df["fuel"].value_counts()
# Out:
# Diesel                  7299
# Super 95                4368
# Gasoline                3252
# Regular                  503
# Super E10 95             409
# CNG                       36
# LPG                       16
# Super Plus 98             11
# Liquid petroleum gas      10
# Others                     6
# Electric                   5
# Super Plus E10 98          2
# Biogas                     1
# Domestic gas H             1
# Name: fuel, dtype: int64

# %%
benzine = ["Gasoline", "Super 95", "Regular", "Super E10 95", "Super Plus 98", "Super Plus E10 98", "Others"]
lpg = ["LPG", "Liquid petroleum gas", "CNG", "Biogas", "Domestic gas H"]

# %%
def fueltype(x):
    if x in benzine:
        return "Benzine"
    elif x in lpg:
        return "LPG/CNG"
    else:
        return x

# %%
df["fuel"] = df.fuel.apply(fueltype)
df["fuel"]
# Out:
# 0         Diesel
# 1        Benzine
# 2         Diesel
# 3         Diesel
# 4         Diesel
#           ...
# 15914     Diesel
# 15915    Benzine
# 15916     Diesel
# 15917     Diesel
# 15918    Benzine
# Name: fuel, Length: 15919, dtype: object

# %%
df["fuel"].value_counts()
# Out:
# Benzine     8551
# Diesel      7299
# LPG/CNG       64
# Electric       5
# Name: fuel, dtype: int64

# %%
df['electricity_consumption'] = df['electricity_consumption'].str[0].str.strip("\n")

# %%
df['electricity_consumption'].value_counts()
# Out:
# 0 kWh/100 km (comb)    137
# Name: electricity_consumption, dtype: int64

# %%
df['other_fuel_types'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [[], [], []]    880
# Name: other_fuel_types, dtype: int64

# %% [markdown]
# ## Consumption

# %%
df["consumption"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [[3.9 l/100 km (comb)], [4.1 l/100 km (city)], [3.7 l/100 km (country)]]              304
# [[4.2 l/100 km (comb)], [5 l/100 km (city)], [3.7 l/100 km (country)]]                276
# [[5.4 l/100 km (comb)], [6.8 l/100 km (city)], [4.5 l/100 km (country)]]              257
# [[3.8 l/100 km (comb)], [4.3 l/100 km (city)], [3.5 l/100 km (country)]]              253
# ...

# %%
df["consumption"].isnull().sum()
# Out:
# 1906

# %%
df["consumption"]
# Out:
# 0        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1        [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2        [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4        [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#                                ...
# 15914    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915    [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918    [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# Name: consumption, Length: 15919, dtype: object

# %%
k=df["consumption"].str[0]
k
# Out:
# 0        [3.8 l/100 km (comb)]
# 1        [5.6 l/100 km (comb)]
# 2        [3.8 l/100 km (comb)]
# 3        [3.8 l/100 km (comb)]
# 4        [4.1 l/100 km (comb)]
#                  ...
# 15914    [5.3 l/100 km (comb)]
# 15915                       \n
# 15916    [5.3 l/100 km (comb)]
# 15917    [5.3 l/100 km (comb)]
# 15918    [6.8 l/100 km (comb)]
# Name: consumption, Length: 15919, dtype: object

# %%
df["consumption_country"] = df['consumption'].str[2].str[0].str.extract('(\d.\d|\d)')
df["consumption_country"] = pd.to_numeric(df["consumption_country"])
df["consumption_country"]
# Out:
# 0        3.5
# 1        4.7
# 2        3.4
# 3        3.5
# 4        3.8
#         ...
# 15914    4.7
# 15915    NaN
# 15916    4.7
# 15917    4.7
# 15918    5.7
# Name: consumption_country, Length: 15919, dtype: float64

# %%
df["consumption_city"]  = df['consumption'].str[1].str[0].str.extract('(\d.\d|\d)')
df["consumption_city"] = pd.to_numeric(df["consumption_city"])
df["consumption_city"]
# Out:
# 0        4.3
# 1        7.1
# 2        4.4
# 3        4.3
# 4        4.6
#         ...
# 15914    6.2
# 15915    7.0
# 15916    6.2
# 15917    6.2
# 15918    8.7
# Name: consumption_city, Length: 15919, dtype: float64

# %%
df["consumption_comb"] = df['consumption'].str[0].str[0].str.extract('(\d.\d|\d)')
df["consumption_comb"] = pd.to_numeric(df["consumption_comb"])
df["consumption_comb"]
# Out:
# 0        3.8
# 1        5.6
# 2        3.8
# 3        3.8
# 4        4.1
#         ...
# 15914    5.3
# 15915    NaN
# 15916    5.3
# 15917    5.3
# 15918    6.8
# Name: consumption_comb, Length: 15919, dtype: float64

# %% [markdown]
# ## Comfort & Convenience

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'k_w', 'hp', 'type',
#        'previous_owners', 'next_inspection', 'inspection_new', 'warranty',
#        'full_service', 'non_smoking_vehicle', 'null', 'make', 'model',
#        'offer_number', 'first_registration', 'body_color', 'paint_type',
#        'body_color_original', 'upholstery', 'body', 'nr_of_doors',
#        'nr_of_seats', 'model_code', 'gearing_type', 'displacement',
#        'cylinders', 'weight', 'drive_chain', 'fuel', 'consumption',
#        'co_2_emission', 'emission_class', 'comfort_&_convenience',
#        'entertainment_&_media', 'extras', 'safety_&_security', 'description',
#        'emission_label', 'gears', 'country_version', 'electricity_consumption',
#        'last_service_date', 'other_fuel_types', 'availability',
#        'last_timing_belt_service_date', 'available_from', 'age',
# ...

# %%
df["comfort_&_convenience"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# ...

# %%
df["comfort_&_convenience"].isnull().sum()
# Out:
# 920

# %%
def listclear(x):
    if type(x)==float: 
        return np.nan 
    else:
        return ",".join(x)

# %%
df["comfort_&_convenience"] = df["comfort_&_convenience"].apply(listclear)

# %%
df["comfort_&_convenience"].value_counts()
# Out:
# Air conditioning,Electrical side mirrors,Hill Holder,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                   216
# Air conditioning,Electrical side mirrors,Power windows                                                                                                                                                                                                                                                                                                                                                                                                                                               134
# ...

# %% [markdown]
# ## Entertainment & Media

# %%
df["entertainment_&_media"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Bluetooth, Hands-free equipment, On-board computer, Radio, USB]                         1282
# [Bluetooth, Hands-free equipment, MP3, On-board computer, Radio, USB]                     982
# [Bluetooth, CD player, Hands-free equipment, MP3, On-board computer, Radio, USB]          783
# [On-board computer, Radio]                                                                487
# ...

# %%
df["entertainment_&_media"].isnull().sum()
# Out:
# 1374

# %%
def listclear(x):
    if type(x)==float: 
        return np.nan 
    else:
        return ",".join(x)

# %%
df["entertainment_&_media"] = df["entertainment_&_media"].apply(listclear)

# %%
df["entertainment_&_media"]
# Out:
# 0        Bluetooth,Hands-free equipment,On-board comput...
# 1        Bluetooth,Hands-free equipment,On-board comput...
# 2                                    MP3,On-board computer
# 3        Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4        Bluetooth,CD player,Hands-free equipment,MP3,O...
#                                ...
# 15914    Bluetooth,Digital radio,Hands-free equipment,O...
# 15915    Bluetooth,Digital radio,Hands-free equipment,R...
# 15916    Bluetooth,Hands-free equipment,On-board comput...
# 15917                    Bluetooth,Digital radio,Radio,USB
# 15918                                                  USB
# Name: entertainment_&_media, Length: 15919, dtype: object

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 6.432565
# registration                      10.032037
# prev_owner                        42.892141
# k_w                              100.000000
# hp                                 0.552799
# type                               0.012564
# previous_owners                   41.711163
# next_inspection                   82.253910
# inspection_new                    75.299956
# warranty                          34.047365
# full_service                      60.864376
# non_smoking_vehicle               78.264966
# null                               0.000000
# make                               0.000000
# model                              0.000000
# ...

# %% [markdown]
# ## Extras

# %%
df["extras"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [Alloy wheels]                                                                                                     3245
# [Alloy wheels, Touch screen]                                                                                        697
# [Alloy wheels, Voice Control]                                                                                       577
# ...

# %%
df["extras"].isnull().sum()
# Out:
# 2962

# %%
df["extras"] = df["extras"].apply(listclear)
df["extras"]
# Out:
# 0           Alloy wheels,Catalytic Converter,Voice Control
# 1        Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                               Alloy wheels,Voice Control
# 3                   Alloy wheels,Sport seats,Voice Control
# 4        Alloy wheels,Sport package,Sport suspension,Vo...
#                                ...
# 15914                            Alloy wheels,Touch screen
# 15915              Alloy wheels,Touch screen,Voice Control
# 15916                                         Alloy wheels
# 15917                            Alloy wheels,Touch screen
# 15918                            Alloy wheels,Touch screen
# Name: extras, Length: 15919, dtype: object

# %% [markdown]
# ## Safety & Security

# %%
df["safety_&_security"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [ABS, Central door lock, Daytime running lights, Driver-side airbag, Electronic stability control, Fog lights, Immobilizer, Isofix, Passenger-side airbag, Power steering, Side airbag, Tire pressure monitoring system, Traction control]                                                                                                                                           538
# ...

# %%
df["safety_&_security"].isnull().sum()
# Out:
# 982

# %%
df["safety_&_security"] = df["safety_&_security"].apply(listclear)

# %%
df["safety_&_security"]
# Out:
# 0        ABS,Central door lock,Daytime running lights,D...
# 1        ABS,Central door lock,Central door lock with r...
# 2        ABS,Central door lock,Daytime running lights,D...
# 3        ABS,Alarm system,Central door lock with remote...
# 4        ABS,Central door lock,Driver-side airbag,Elect...
#                                ...
# 15914    ABS,Central door lock,Central door lock with r...
# 15915    ABS,Adaptive Cruise Control,Blind spot monitor...
# 15916    ABS,Adaptive Cruise Control,Blind spot monitor...
# 15917    ABS,Blind spot monitor,Driver-side airbag,Elec...
# 15918    ABS,Blind spot monitor,Daytime running lights,...
# Name: safety_&_security, Length: 15919, dtype: object

# %% [markdown]
# ## Country version

# %%
df["country_version"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nGermany\n]           4502
# [\nItaly\n]             1038
# [\nEuropean Union\n]     507
# [\nNetherlands\n]        464
# [\nSpain\n]              325
# [\nBelgium\n]            314
# [\nAustria\n]            208
# [\nCzech Republic\n]      52
# [\nPoland\n]              49
# [\nFrance\n]              38
# [\nDenmark\n]             33
# [\nHungary\n]             28
# [\nJapan\n]                8
# ...

# %%
df["country_version"] = df["country_version"].str[0].str.strip("\n")
df["country_version"]
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4        Germany
#           ...
# 15914        NaN
# 15915    Germany
# 15916    Austria
# 15917        NaN
# 15918    Germany
# Name: country_version, Length: 15919, dtype: object

# %%
df["country_version"].value_counts()
# Out:
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64

# %% [markdown]
# ## Last Service Date (Drop)

# %%
df.last_service_date.isnull().sum()*100/df.shape[0]
# Out:
# 96.44450028268108

# %%
df.isnull().sum()*100/df.shape[0]
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 6.432565
# registration                      10.032037
# prev_owner                        42.892141
# k_w                              100.000000
# hp                                 0.552799
# type                               0.012564
# previous_owners                   41.711163
# next_inspection                   82.253910
# inspection_new                    75.299956
# warranty                          34.047365
# full_service                      60.864376
# non_smoking_vehicle               78.264966
# null                               0.000000
# make                               0.000000
# model                              0.000000
# ...

# %% [markdown]
# ## Availability (Drop)

# %%
df["availability"].value_counts()
# Out:
# \nin 90 days from ordering\n     196
# \nin 120 days from ordering\n    182
# \nin 1 day from ordering\n        51
# \nin 5 days from ordering\n       35
# \nin 3 days from ordering\n       35
# \nin 180 days from ordering\n     24
# \nin 14 days from ordering\n      24
# \nin 7 days from ordering\n       20
# \nin 150 days from ordering\n     18
# \nin 2 days from ordering\n       16
# \nin 60 days from ordering\n      13
# \nin 42 days from ordering\n      10
# \nin 21 days from ordering\n       8
# \nin 4 days from ordering\n        2
# \nin 6 days from ordering\n        1
# Name: availability, dtype: int64

# %%
df.availability.isnull().sum()*100/df.shape[0]
# Out:
# 96.01105597085244

# %% [markdown]
# ## Available From(Drop)

# %%
df["available_from"].value_counts()
# Out:
# \n31/08/19\n    98
# \n30/07/19\n    25
# \n15/08/19\n    24
# \n16/09/19\n    14
# \n29/06/19\n    12
# \n01/07/19\n    11
# \n28/06/19\n    10
# \n19/08/19\n     7
# \n10/09/19\n     6
# \n26/06/19\n     5
# \n27/06/19\n     5
# \n10/11/19\n     5
# \n08/07/19\n     4
# \n25/10/19\n     3
# \n15/07/19\n     3
# \n01/08/19\n     3
# \n04/07/19\n     2
# \n05/08/19\n     2
# \n24/08/19\n     2
# \n16/07/19\n     2
# \n20/07/19\n     2
# \n05/07/19\n     2
# \n30/06/19\n     2
# \n30/09/19\n     1
# \n31/10/19\n     1
# \n27/07/19\n     1
# \n02/07/19\n     1
# \n10/07/19\n     1
# \n19/07/19\n     1
# \n24/07/19\n     1
# \n29/07/19\n     1
# \n29/09/19\n     1
# \n18/08/19\n     1
# \n14/09/19\n     1
# \n18/07/19\n     1
# \n16/08/19\n     1
# \n24/09/19\n     1
# \n17/08/19\n     1
# \n10/10/19\n     1
# \n06/12/19\n     1
# \n03/12/19\n     1
# \n05/12/19\n     1
# \n11/08/19\n     1
# \n10/12/19\n     1
# \n01/09/19\n     1
# \n03/08/19\n     1
# ...

# %%
df.available_from.isnull().sum()*100/df.shape[0]
# Out:
# 98.29134995916829

# %% [markdown]
# ## Last Timing Belt Service Date (Drop)

# %%
df["last_timing_belt_service_date"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\n04/2016\n]                2
# [\n12/1900\n]                1
# [\n07/2018\n]                1
# [\n01/1900\n]                1
# [\n05/2019\n]                1
# [\n09/2018\n]                1
# [\n05/2018\n, \nEuro 6\n]    1
# [\n06/2017\n]                1
# [\n01/2019\n]                1
# [\n02/2019\n]                1
# [\n02/2018\n]                1
# [\n06/2019\n]                1
# [\n01/2018\n]                1
# ...

# %%
df.last_timing_belt_service_date.isnull().sum()*100/df.shape[0]
# Out:
# 99.89949117406873

# %%
df.T
# Out:
#                                                                            0      \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                         56013
# registration                                                 2016-01-01 00:00:00
# prev_owner                                                                     2
# k_w                                                                          NaN
# hp                                                                            66
# ...

# %%
df.to_csv("cleardata.csv", index=False)
